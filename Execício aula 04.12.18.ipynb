# %% [markdown]
# # Exercício em aula - Análise da base de passagens áreas - 04.12.2018

# %%
# Importa boblioteca
import pandas as pd

# %%
#Ler o arquivo e tira as 2 primeiras linhas do arquivo
df = pd.read_excel('201710_EmissaoPassagens_SCDP.xlsx', skiprows=3, skipfooter=3)

# %%
# verificar as 5 primeiras linhas do Dataframe
df.head()
# Out:
#     Código do órgão superior  \
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
#
#                                  Nome do órgão superior                                  \
# 0   Fundação Instituto Brasileiro de Geografia e ...
# 1   Fundação Instituto Brasileiro de Geografia e ...
# 2   Fundação Instituto Brasileiro de Geografia e ...
# 3   Fundação Instituto Brasileiro de Geografia e ...
# 4   Fundação Instituto Brasileiro de Geografia e ...
#
#     Código do órgão solicitante da viagem  \
# 0                                       3
# 1                                       3
# 2                                       3
# 3                                       3
# 4                                       3
#
#                                         Nome do órgão solicitante da viagem                                         \
# ...

# %%
# Verificar as 5 últimas linhas
df.tail()
# Out:
#         Código do órgão superior  \
# 50400                     219924
# 50401                     219924
# 50402                     219924
# 50403                     219924
# 50404                     219924
#
#                                      Nome do órgão superior                                  \
# 50400   Secretaria-Geral da Presidência da República ...
# 50401   Secretaria-Geral da Presidência da República ...
# 50402   Secretaria-Geral da Presidência da República ...
# 50403   Secretaria-Geral da Presidência da República ...
# 50404   Secretaria-Geral da Presidência da República ...
#
#         Código do órgão solicitante da viagem  \
# 50400                                   84010
# 50401                                   84010
# 50402                                   84010
# 50403                                   34889
# 50404                                   34889
#
# ...

# %%
# Retira os espaços das colunas
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df.dtypes
# Out:
# Código do órgão superior                   int64
# Nome do órgão superior                    object
# Código do órgão solicitante da viagem      int64
# Nome do órgão solicitante da viagem       object
# N. PCDP                                   object
# N. Reserva/Localizador                    object
# Data Emissão Bilhete                      object
# Data Embarque                             object
# Valor Tarifa Comercial                   float64
# Percentual Desconto Aplicado             float64
# Valor Tarifa Governo                     float64
# Valor Tarifa Embarque                    float64
# Valor Bilhete                            float64
# Companhia Aérea                           object
# Classe Tarifária Bilhete                  object
# Regra Tarifária                           object
# No Show                                   object
# Remarcado                                 object
# Cancelado                                 object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50405 entries, 0 to 50404
# Data columns (total 23 columns):
# Código do órgão superior                 50405 non-null int64
# Nome do órgão superior                   50405 non-null object
# Código do órgão solicitante da viagem    50405 non-null int64
# Nome do órgão solicitante da viagem      50405 non-null object
# N. PCDP                                  50405 non-null object
# N. Reserva/Localizador                   50405 non-null object
# Data Emissão Bilhete                     50405 non-null object
# Data Embarque                            50405 non-null object
# Valor Tarifa Comercial                   50405 non-null float64
# Percentual Desconto Aplicado             50405 non-null float64
# Valor Tarifa Governo                     50405 non-null float64
# Valor Tarifa Embarque                    50405 non-null float64
# Valor Bilhete                            50405 non-null float64
# ...

# %%
# Gera as estatísticas da base
df.describe()
# Out:
#        Código do órgão superior  Código do órgão solicitante da viagem  \
# count              50405.000000                           50405.000000
# mean               16489.825176                           47696.792084
# std                36709.186923                           50214.945925
# min                    3.000000                         -122771.000000
# 25%                  315.000000                            3418.000000
# 50%                  471.000000                           32207.000000
# 75%                 2207.000000                           86558.000000
# max               219924.000000                          224227.000000
#
#        Valor Tarifa Comercial  Percentual Desconto Aplicado  \
# count            50405.000000                  50405.000000
# mean               678.273258                      2.078992
# std                432.242664                      3.211066
# min                  0.000000                     -6.640000
# ...

# %%
df['Valor Tarifa Comercial'].value_counts()
# Out:
# 299.00     203
# 349.90     182
# 559.00     180
# 321.90     162
# 389.00     148
# 439.00     144
# 205.00     142
# 199.90     140
# 299.90     127
# 545.00     122
# 555.00     121
# 769.00     121
# 359.00     119
# 619.00     117
# 419.00     115
# 575.00     115
# 405.00     114
# 499.00     112
# 0.00       111
# 269.00     110
# 449.90     108
# 605.00     107
# 1590.90    106
# 425.00     102
# 418.90     102
# 289.90     101
# 1828.90     99
# 475.00      98
# 390.90      97
# 340.90      96
#           ...
# 2701.80      1
# 1355.00      1
# 1059.04      1
# 1656.80      1
# 1073.69      1
# 1107.80      1
# 330.80       1
# 1682.58      1
# 1324.80      1
# 2908.80      1
# 1229.00      1
# 1937.80      1
# 2429.80      1
# 630.10       1
# 1634.00      1
# 320.17       1
# 1110.80      1
# 2241.80      1
# 740.88       1
# 1584.01      1
# 344.80       1
# 2131.96      1
# 1211.80      1
# 2610.80      1
# 2063.80      1
# 1391.95      1
# 1768.05      1
# ...

# %%
df['Valor Tarifa Governo'].value_counts()
# Out:
# 542.23     218
# 528.65     188
# 745.93     175
# 339.40     170
# 436.40     166
# 406.43     161
# 586.85     160
# 290.90     152
# 425.83     144
# 223.97     142
# 324.95     138
# 330.67     138
# 392.85     133
# 281.20     132
# 290.03     129
# 775.90     128
# 484.03     125
# 205.00     122
# 557.75     119
# 260.93     118
# 349.10     117
# 193.90     117
# 321.90     109
# 232.70     108
# 299.00     107
# 417.00     106
# 242.40     103
# 397.60      99
# 489.85      98
# 328.83      98
#           ...
# 1519.69      1
# 950.80       1
# 1639.30      1
# 1730.28      1
# 1907.02      1
# 2916.69      1
# 1638.90      1
# 505.30       1
# 264.00       1
# 1744.90      1
# 1077.47      1
# 734.29       1
# 837.80       1
# 1972.98      1
# 1383.90      1
# 2160.96      1
# 1384.19      1
# 809.75       1
# 247.50       1
# 1782.00      1
# 1042.00      1
# 1065.06      1
# 368.41       1
# 562.02       1
# 698.98       1
# 395.56       1
# 902.23       1
# ...

# %%
df['Nome do órgão superior'].sample(10)
# Out:
# 27915     Departamento de Polícia Rodoviária Federal   ...
# 48484     Instituto Federal de Educação, Ciência e Tecn...
# 5356      Comissão Nacional de Energia Nuclear         ...
# 35521     Instituto Nacional do Seguro Social          ...
# 42892     Secretaria de Governo da Presidência da Repúb...
# 20089     Universidade Federal do Rio de Janeiro       ...
# 2830      Comando da Aeronáutica                       ...
# 48626     Instituto Federal de Educação, Ciência e Tecn...
# 34325     Ministério da Fazenda                        ...
# 39564     Ministério do Trabalho                       ...
# Name: Nome do órgão superior, dtype: object

# %%
df[['Valor Tarifa Governo','Valor Tarifa Comercial']].sample(10)
# Out:
#        Valor Tarifa Governo  Valor Tarifa Comercial
# 29503               1906.05                 1906.05
# 184                  316.90                  316.90
# 14510                522.73                  538.90
# 26925                590.90                  590.90
# 26435                647.90                  647.90
# 44537                489.85                  505.00
# 45689                262.77                  270.90
# 38459                691.41                  712.80
# 32410                808.88                  833.90
# 25217                631.37                  650.90

# %%
# %matplotlib inline

# %%
df['Nome do órgão superior'].value_counts().plot.bar()

# %%
# Quantidade de voos por orgão superior
df['Nome do órgão superior'].value_counts()
# Out:
#  Ministério da Fazenda                                                                   2949
#  Departamento de Polícia Federal                                                         2664
#  Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira                  2561
#  Ministério da Saúde                                                                     2356
#  Departamento de Polícia Rodoviária Federal                                              1600
#  Instituto Nacional do Seguro Social                                                     1426
#  Comando do Exército                                                                     1315
#  Ministério da Educação                                                                  1170
#  Comando da Aeronáutica                                                                  1156
#  Ministério da Justiça                                                                   1061
# ...

# %%
#df.rename(columns=lambda x: x.strip(), inplace=True)
# Quantidade de voos por orgão superior
df['Nome do órgão solicitante da viagem'].value_counts()
# Out:
#  Diretoria de Avaliação da Educação Superior                                                                        1988
#  Gabinete                                                                                                           1833
#  Reitoria                                                                                                           1499
#  Pró-Reitoria de Pesquisa e Pós-Graduação                                                                           1078
#  Grupamento de Apoio de Brasília                                                                                     830
#  Departamento Penitenciário Nacional                                                                                 628
#  Gabinete do Ministro                                                                                                537
#  Secretaria de Inspeção do Trabalho                                                                                  519
# ...

# %%
df_novo['Público no ano de exibição'].max

# %%
# Analisando a situação final dos voos
df['Situação Final Bilhete'].value_counts().plot.bar()

# %%
# Quantidade de voos por Companhias areas 
df['Companhia Aérea'].value_counts().plot.bar()

# %%
df.nunique()
# Out:
# Código do órgão superior                   180
# Nome do órgão superior                     180
# Código do órgão solicitante da viagem     2532
# Nome do órgão solicitante da viagem       2019
# N. PCDP                                  17711
# N. Reserva/Localizador                   50402
# Data Emissão Bilhete                     50405
# Data Embarque                            15214
# Valor Tarifa Comercial                    6281
# Percentual Desconto Aplicado               349
# Valor Tarifa Governo                      6845
# Valor Tarifa Embarque                       79
# Valor Bilhete                            13685
# Companhia Aérea                              6
# Classe Tarifária Bilhete                   372
# Regra Tarifária                              6
# No Show                                      2
# Remarcado                                    2
# Cancelado                                    2
# Valor Multas                                 7
# ...

# %%
df['Valor Tarifa Comercial'].max()
# Out:
# 4156.8

# %%
df[df['Valor Tarifa Comercial'] == df['Valor Tarifa Comercial'].max()]
# Out:
#        Código do órgão superior  \
# 21541                       431
#
#                                   Nome do órgão superior  \
# 21541   Universidade Federal de Santa Maria          ...
#
#        Código do órgão solicitante da viagem  \
# 21541                                  27563
#
#                      Nome do órgão solicitante da viagem          N. PCDP  \
# 21541   Pró-Reitoria de Pós-Graduação e Pesquisa     ...   004488/17
#
#          N. Reserva/Localizador      Data Emissão Bilhete  \
# 21541   OBF73Z                    2017-10-30 10:00:57.624
#
#               Data Embarque  Valor Tarifa Comercial  \
# 21541   2017-11-06 06:10:00                  4156.8
#
#        Percentual Desconto Aplicado           ...            \
# 21541                           3.0           ...
#
#                               Companhia Aérea    Classe Tarifária Bilhete  \
# 21541   AZUL LINHAS AÉREAS BRASILEIRA           Y,Y,Y/G,G,G
#
# ...

# %%
df[df['Valor Tarifa Comercial'] == df['Valor Tarifa Comercial'].min() ]
# Out:
#        Código do órgão superior  \
# 193                           3
# 194                           3
# 195                           3
# 1590                         14
# 2292                         46
# 2658                         48
# 4666                         94
# 5980                        244
# 5987                        244
# 6734                        244
# 7327                        249
# 7696                        249
# 7777                        249
# 9259                        249
# 9722                        260
# 9724                        260
# 9725                        260
# 9734                        260
# 10641                       304
# 11495                       304
# 11497                       304
# 12245                       315
# 12459                       315
# 14604                       324
# 14938                       324
# 15816                       324
# 17281                       416
# 17798                       419
# ...
